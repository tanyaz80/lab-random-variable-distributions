# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re
#Import the necessary libraries.

# %% [markdown]
# ## Lab | Random variable distributions

# %%
#Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# ## 1. Get the numerical variables from our dataset.

# %%
X = customer_df.select_dtypes(np.number)
X.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %% [markdown]
# ## 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
#I couldn't find the normal distribution.

# %%
sns.displot(X['Customer Lifetime Value'])
plt.show()
#Customer Lifetime Value  looks like exponentional distribution

sns.displot(X['Income'])
plt.show()

sns.displot(X['Monthly Premium Auto'])
plt.show()

sns.displot(X['Months Since Last Claim'])
plt.show()

# %%
sns.displot(X['Months Since Policy Inception'])
plt.show()

sns.displot(X['Number of Open Complaints'])
plt.show()

sns.displot(X['Number of Policies'])
plt.show()
#Number of Open Complaints and Number of Policies - they look like exponentional distribution.
sns.displot(X['Total Claim Amount'])
plt.show()

# %% [markdown]
# ## 3.Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import StandardScaler

# Scaling data
transformer = MinMaxScaler().fit(X) # need to keep transformer
X_train_normalized = transformer.transform(X)
X_train_norm = pd.DataFrame(X_train_normalized, columns=X.columns)

# %%
sns.displot(X_train_norm['Customer Lifetime Value'])
plt.show()
#Customer Lifetime Value  looks like exponentional distribution

sns.displot(X_train_norm['Income'])
plt.show()

sns.displot(X_train_norm['Monthly Premium Auto'])
plt.show()

sns.displot(X_train_norm['Months Since Last Claim'])
plt.show()

# %%
sns.displot(X_train_norm['Months Since Policy Inception'])
plt.show()

sns.displot(X_train_norm['Number of Open Complaints'])
plt.show()

sns.displot(X_train_norm['Number of Policies'])
plt.show()
#Number of Open Complaints and Number of Policies - they look like exponentional distribution.
sns.displot(X_train_norm['Total Claim Amount'])
plt.show()

# %%
#After minimix scaler no changes in graphs

# %%
from sklearn.preprocessing import StandardScaler
Standardtransformer = StandardScaler().fit(X)
x_standardized = Standardtransformer.transform(X)
print(x_standardized.shape)
x_standardized = pd.DataFrame(x_standardized,columns=X.columns)
x_standardized.head()
# Out:
# (9134, 8)
#    Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0                -0.762878  0.612827             -0.703925
# 1                -0.149245 -1.239617              0.022691
# 2                 0.710636  0.365710              0.429596
# 3                -0.052263 -1.239617              0.371467
# 4                -0.755575  0.203390             -0.587666
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                 1.678099                      -1.543287
# 1                -0.208186                      -0.217334
# 2                 0.288205                      -0.360680
# 3                 0.288205                       0.606907
# 4                -0.307465                      -0.145661
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                   -0.42225           -0.822648           -0.169640
# 1                   -0.42225            2.106160            2.400737
# ...

# %%
sns.displot(x_standardized['Customer Lifetime Value'])
plt.show()
#Customer Lifetime Value  looks like exponentional distribution

sns.displot(x_standardized['Income'])
plt.show()

sns.displot(x_standardized['Monthly Premium Auto'])
plt.show()

sns.displot(x_standardized['Months Since Last Claim'])
plt.show()

# %%
sns.displot(x_standardized['Months Since Policy Inception'])
plt.show()

sns.displot(x_standardized['Number of Open Complaints'])
plt.show()

sns.displot(x_standardized['Number of Policies'])
plt.show()
#Number of Open Complaints and Number of Policies - they look like exponentional distribution.
sns.displot(x_standardized['Total Claim Amount'])
plt.show()

# %%
##After standardscaler no changes in graphs

# %%
#sns.distplot(x_standardized['Customer Lifetime Value']) # normalized 
sns.distplot(X['Customer Lifetime Value'].apply(lambda x:np.log(x))) 
sns.distplot(x_standardized['Customer Lifetime Value'].apply(lambda x:np.log(x))) 
plt.show()
#this graph looks a lot like normal distribution but after using the standartization.
#if we put clean X- it's a blue graph
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\tanya\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#sns.distplot(x_standardized['Income']) # normalized lambda x:np.log(x) if x>0 else x
#sns.distplot(x_standardized['Income'].apply(lambda x:np.log(x) if x>0 else x))
sns.distplot(x_standardized['Income'].apply(lambda x:np.log(x))) # divide by twelve to get a 0-1 scale #log distrib
plt.show()

# %%
#sns.distplot(x_standardized['Monthly Premium Auto']) # normalized 
sns.distplot(X['Monthly Premium Auto'].apply(lambda x:np.log(x))) # divide by twelve to get a 0-1 scale #log distrib
plt.show()
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#sns.distplot(x_standardized['Months Since Last Claim']) # normalized 
sns.distplot(x_standardized['Months Since Last Claim'].apply(lambda x:np.log(x))) # divide by twelve to get a 0-1 scale #log distrib
plt.show()

# %%
#sns.distplot(x_standardized['Months Since Last Claim']) # normalized 
sns.distplot(x_standardized['Months Since Policy Inception'].apply(lambda x:np.log(x))) # divide by twelve to get a 0-1 scale #log distrib
plt.show()
# I couldn't make a graph with an X, we need normalized data

# %%
#sns.distplot(x_standardized['Months Since Last Claim']) # normalized 
sns.distplot(x_standardized['Number of Open Complaints'].apply(lambda x:np.log(x))) # divide by twelve to get a 0-1 scale #log distrib
plt.show()

# %%
sns.distplot(X['Number of Policies'].apply(lambda x:np.log(x))) # divide by twelve to get a 0-1 scale #log distrib
plt.show()
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(x_standardized['Total Claim Amount'].apply(lambda x:np.log(x))) # divide by twelve to get a 0-1 scale #log distrib
plt.show()
#this graph looks a lot like normal distribution
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_log = np.log(X)

# %%
sns.distplot(data_log['Total Claim Amount']) # divide by twelve to get a 0-1 scale #log distrib
plt.show()
# Out:
# C:\Users\tanya\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Not every graph can be built using log transformation. Some of them needed normalization. ALso depending on different graph some
# standartization changed the log transformation. Total Calim Amount looks closer to normal distribution after applying on clean x and on normalized data.
